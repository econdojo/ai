# %% [markdown]
# # Problem Set 1: Python Fundamentals
#
# **Course:** Introduction to Neural Networks
# **Instructor:** Fei Tan
# **Due Date:** September 24, 2025, 6:00 PM
#
# ---
#
# ## Submission Instructions
#
# **Important:** Please read these instructions carefully before starting.
#
# 1. **LaTeX Requirement:** Type up all your mathematical work, explanations, and answers in LaTeX. You may use any LaTeX editor (e.g., VS Code, Overleaf, etc.).
#
# 2. **Code Submission:** Complete all programming exercises in this Jupyter notebook. Make sure all cells run without errors.
#
# 3. **GitHub Classroom Submission:** Upload ALL source files to GitHub Classroom:
#    - Your completed Jupyter notebook (`lastname_firstname.ipynb` file)
#    - Your LaTeX source files (`lastname_firstname.tex` file)
#    - Compiled PDF of your LaTeX document (`lastname_firstname.pdf` file)
#    - Any additional Python files if created
#
# 4. **Academic Integrity:** This is an individual assignment. You may discuss concepts with classmates and AI agents, but all work submitted must be your own.
#
# ---

# %% [markdown]
# ## Problem 1: Basic Data Types (4 points)
#
# ### Part A: Number Operations
#
# Write Python code to perform the following operations. For each part, print both the result and its type.

# %%
# 1.A.1: Create two variables: x = 15, y = 4.0
# Perform and print: addition, subtraction, multiplication, division, integer division, modulo, and exponentiation
# Your code here

# %%
# 1.A.2: Demonstrate the difference between int and float division
# Show what happens when you divide 7 by 2 using / and //
# Your code here

# %% [markdown]
# ### Part B: String Manipulation
#
# Given the string `text = "Python Programming Language"`:

# %%
text = "Python Programming Language"

# 1.B.1: Convert the string to lowercase and print the result
# Your code here

# 1.B.2: Replace all spaces with underscores and print the result
# Your code here

# 1.B.3: Extract and print the substring "Programming" using string slicing
# Your code here

# 1.B.4: Count and print the number of words in the string
# Your code here

# %% [markdown]
# ### Part C: Boolean Logic
#
# Write expressions that evaluate to `True` or `False` as specified:

# %%
a, b, c = 10, 20, 15

# 1.C.1: Write an expression that checks if a is less than b AND b is greater than c
# Your code here

# 1.C.2: Write an expression that checks if a is NOT equal to c OR c is equal to 15
# Your code here

# %% [markdown]
# ---
#
# ## Problem 2: Data Structures and Containers (4 points)
#
# ### Part A: Lists and List Comprehensions

# %%
# 2.A.1: Create a list of the first 10 positive integers
# Your code here

# 2.A.2: Using list comprehension, create a list of squares of even numbers from 0 to 20
# Your code here

# 2.A.3: Given the list below, use slicing to extract every third element
data = [1, 4, 7, 2, 9, 5, 3, 8, 6, 0, 12, 15, 18]
# Your code here

# 2.A.4: Reverse the list using slicing (not the reverse() method)
# Your code here

# %% [markdown]
# ### Part B: Dictionaries
#
# You are given data about programming languages and their year of creation:

# %%
# 2.B.1: Create a dictionary with programming languages as keys and their year of creation as values
# Include: Python (1991), Java (1995), JavaScript (1995), C++ (1985), Go (2009)
# Your code here

# 2.B.2: Add a new entry for "Rust" with year 2010
# Your code here

# 2.B.3: Use dictionary comprehension to create a new dictionary with languages created after 1990
# Your code here

# 2.B.4: Print all languages and their years in a formatted way
# Your code here

# %% [markdown]
# ---
#
# ## Problem 3: Functions and Classes (4 points)
#
# ### Part A: Functions

# %%
# 3.A.1: Write a function called 'calculate_stats' that takes a list of numbers
# and returns a dictionary with 'mean', 'max', 'min', and 'count' keys
# Include a parameter 'verbose' (default False) that prints the input when True

def calculate_stats(numbers, verbose=False):
    # Your code here
    pass

# Test your function
test_data = [1, 5, 3, 9, 2, 8, 4]
print(calculate_stats(test_data))
print(calculate_stats(test_data, verbose=True))

# %%
# 3.A.2: Write a function 'filter_and_transform' that:
# - Takes a list of numbers and a threshold value
# - Returns a list containing only numbers greater than the threshold, squared
# - Use list comprehension inside the function

def filter_and_transform(numbers, threshold):
    # Your code here
    pass

# Test your function
test_numbers = [1, 5, 3, 9, 2, 8, 4]
result = filter_and_transform(test_numbers, 4)
print(f"Original: {test_numbers}")
print(f"Filtered and squared (> 4): {result}")

# %% [markdown]
# ### Part B: Classes
#
# Create a simple class hierarchy:

# %%
# 3.B.1: Create a base class 'Shape' with the following:
# - Constructor that takes 'name' parameter
# - Method 'get_info()' that returns a string with shape name
# - Method 'area()' that raises NotImplementedError

class Shape:
    # Your code here
    pass

# 3.B.2: Create a 'Rectangle' class that inherits from 'Shape':
# - Constructor takes 'width' and 'height' parameters (call super() with "Rectangle")
# - Override 'area()' to return width * height
# - Override 'get_info()' to include dimensions

class Rectangle(Shape):
    # Your code here
    pass

# Test your classes
rect = Rectangle(5, 3)
print(rect.get_info())
print(f"Area: {rect.area()}")

# %% [markdown]
# ---
#
# ## Problem 4: NumPy Fundamentals (4 points)
#
# ### Part A: Array Creation and Basic Operations

# %%
import numpy as np

# 4.A.1: Create the following arrays:
# - A 3x4 array of zeros
# - A 2x2 identity matrix
# - A 1D array of 10 evenly spaced numbers between 0 and 1
# - A 3x3 array filled with the value 7
# Your code here

# %%
# 4.A.2: Given the array below, perform the following operations:
arr = np.arange(1, 25).reshape(4, 6)
print("Original array:")
print(arr)

# Extract the second row
# Your code here

# Extract the last two columns
# Your code here

# Extract elements greater than 15
# Your code here

# %% [markdown]
# ### Part B: Array Operations and Broadcasting

# %%
# 4.B.1: Create two 3x3 random arrays and perform element-wise operations
np.random.seed(42)  # For reproducibility
A = np.random.rand(3, 3)
B = np.random.rand(3, 3)

print("Array A:")
print(A)
print("\nArray B:")
print(B)

# Compute and print: A + B, A * B, sqrt(A)
# Your code here

# %%
# 4.B.2: Broadcasting exercise
# Create a 4x3 matrix of random values
# Create a 1D array [1, 2, 3]
# Add the array to each row of the matrix using broadcasting
# Print both the original matrix and the result
# Your code here

# %% [markdown]
# ---
#
# ## Problem 5: PyTorch Fundamentals (4 points)
#
# ### Part A: Tensor Creation and Basic Operations

# %%
# Install PyTorch if needed (uncomment the line below)
# !pip install torch

import torch

# 5.A.1: Create the following tensors:
# - A 1D tensor with values [1, 2, 3, 4, 5]
# - A 2x3 tensor of zeros
# - A 3x3 tensor of ones
# - A 2x2 random tensor
# Print each tensor and its shape
# Your code here

# %%
# 5.A.2: Tensor operations
# Create two 2x3 tensors with random values
# Perform and print the results of: addition, multiplication, matrix transpose
# Convert one tensor to NumPy array and back to tensor
# Your code here

# %% [markdown]
# ### Part B: Tensor Indexing and Reshaping

# %%
# 5.B.1: Tensor indexing and slicing
# Create a 4x4 tensor with values from 1 to 16
# Extract the second row, last column, and a 2x2 submatrix from the center
# Your code here

# %%
# 5.B.2: Tensor reshaping and view operations
# Create a 1D tensor with 12 elements (values 0 to 11)
# Reshape it to 3x4, then to 2x6, then use view() to create a 4x3 tensor
# Demonstrate the difference between reshape() and view()
# Your code here
